# %%
from gensim.models.fasttext import load_facebook_vectors

path = "cc.pl.300.bin"

model = load_facebook_vectors(path)

# %%
def get_similar_words(word, topn=10):
    try:
        similar = model.most_similar(word, topn=topn)
        return [w for w, score in similar]
    except KeyError:
        return []

# %%
import re
import simplemma

def lemmatize(word):
    return simplemma.lemmatize(word, lang="pl")

def group_similar_words_word2vec(text, threshold=0.7):

    words = re.findall(r'\b[a-zA-Ząćęłńóśźż]+\b', text.lower())
    # words_lem = [lemmatize(w) for w in words]
    words_in_text = set(words)

    grouped = {}
    seen = set()

    for w in words_in_text:
        if len(w) < 3:
            continue
        if w in seen or w not in model:
            continue
        
        similar = [
            (word, score)
            for word, score in model.most_similar(w, topn=50)
            if word in words_in_text and score > threshold
        ]

        if similar:
            group = {word for word, _ in similar}
            group.discard(w)

            if group:
                grouped[w] = sorted(group)
                seen.update(group)
                seen.add(w)

    return grouped

# %%
with open("tekst.txt", "r", encoding="utf-8") as f:
    tekst = f.read()

wynik = group_similar_words_word2vec(tekst)

for rep, group in wynik.items():
    print(f"{rep}: {group}")

with open("results.txt", "w", encoding="utf-8") as out:
    for rep, group in wynik.items():
        out.write(f"{rep}: {group}\n")
# Out:
# musi: ['być', 'może', 'powinien']
# udzielonych: ['udzielonej']
# roszczeń: ['roszczenia']
# potwierdzającego: ['stwierdzającego']
# wykonany: ['wykonane']
# zobligowany: ['zobowiązany']
# zawarcie: ['zawarcia']
# momencie: ['chwili']
# miała: ['mająca', 'miał', 'miało', 'mogła']
# maja: ['grudnia', 'lipca', 'lutego', 'października', 'sierpnia', 'września']
# uzasadnione: ['nieuzasadnione', 'zasadne']
# przeprowadzeniu: ['przeprowadzenia']
# więc: ['ale', 'bowiem', 'choć', 'jednak', 'jednakże', 'natomiast', 'ponieważ', 'też', 'wtedy', 'zatem']
# zakwestionował: ['kwestionował']
# ustalone: ['określone']
# polega: ['polegająca']
# zapłaty: ['zapłacenia']
# również: ['bowiem', 'jednak', 'ponadto', 'także', 'też', 'tylko']
# ograniczenia: ['ograniczenie']
# jakichkolwiek: ['jakiejkolwiek']
# stanowiły: ['stanowią', 'stanowił', 'stanowiło']
# zasądza: ['zasądzenia', 'zasądzenie', 'zasądził']
# wypadku: ['przypadku']
# kolejne: ['dwa', 'pierwsze']
# wykonawcę: ['wykonawcy']
# przewidzianych: ['określonych']
# wszystkim: ['przede']
# zgodne: ['zgodnie']
# drugie: ['pierwsze']
# protokołem: ['protokole']
# protokół: ['protokołu']
# powyższego: ['tego']
# naruszenia: ['naruszenie']
# stwierdził: ['podkreślił', 'potwierdził', 'twierdzi', 'uznał', 'wskazał']
# należało: ['należy']
# prejudycjalne: ['prejudycjalnych']
# winien: ['powinien']
# wymienionych: ['wskazanych']
# pozostaje: ['pozostają', 'pozostała']
# takiego: ['innego', 'tego']
# dowodów: ['dowody']
# zarzutu: ['zarzutów']
# stanowiska: ['stanowisko']
# spełnienie: ['spełnienia']
# oddziałuje: ['wpływa']
# gdy: ['jeżeli', 'kiedy', 'wtedy']
# spółki: ['spółce']
# wydanie: ['wydania']
# dokonanie: ['dokonania']
# było: ['mogło']
# wskazanym: ['określonym']
# zarzuty: ['zarzut']
# dokonał: ['dokonać', 'dokonuje']
# opłat: ['opłaty']
# kolejnym: ['każdym', 'pierwszym', 'takim']
# artykuł: ['tekst']
# polegające: ['polegająca']
# wykonania: ['wykonanie']
# zawierało: ['zawierał']
# przedstawienia: ['przedstawienie']
# twierdzić: ['sądzić']
# mogą: ['mają', 'mogące']
# jej: ['ich', 'jego']
# prac: ['pracach']
# zawierać: ['zawiera', 'zawierał']
# mówić: ['powiedzieć']
# umowie: ['umowy']
# zagadnienia: ['zagadnienie']
# nastąpić: ['nastąpi', 'następuje']
# spełniały: ['spełniał']
# była: ['pozostała']
# nieistotne: ['istotne']
# określeniu: ['ustaleniu']
# niewykonania: ['niewykonanie']
# zobowiązanie: ['zobowiązania']
# albowiem: ['gdyż', 'jednakże', 'ponieważ']
# nastąpiło: ['nastąpi']
# zarazem: ['jednocześnie']
# nieprawidłowe: ['prawidłowe']
# postaci: ['formie']
# uprawnienia: ['uprawnienie', 'uprawnień']
# usunięcie: ['usunięcia']
# dotyczył: ['dotyczy', 'dotyczyła', 'dotyczyły', 'dotyczący']
# celem: ['zadaniem']
# niniejszego: ['niniejszej']
# powyższym: ['niniejszym']
# ponoszenia: ['poniesienia']
# jedynie: ['bowiem', 'tylko', 'wprawdzie', 'wyłącznie']
# podczas: ['trakcie']
# oświadczenie: ['oświadczenia']
# spełnieniu: ['spełnienia']
# wystąpiły: ['występowały']
# taki: ['sam', 'ten']
# kwestia: ['sprawa']
# niej: ['nich', 'niego', 'nim']
# prejudycjalna: ['prejudycjalne', 'prejudycjalnych']
# dotycząca: ['dotyczyła']
# żądania: ['żądanie']
# prejudycjalności: ['prejudycjalne', 'prejudycjalnych']
# stanowi: ['stanowią', 'stanowił', 'stanowiło']
# takie: ['podobne']
# pozwanego: ['powoda', 'pozwanej', 'pozwaną']
# pomiędzy: ['między']
# powyższymi: ['stosownymi']
# którego: ['którym']
# gwarancja: ['gwarancji', 'gwarancją', 'gwarancję']
# lub: ['albo']
# wskazując: ['wskazał']
# wady: ['wad']
# wyniku: ['skutek']
# dzieło: ['dzieła']
# której: ['którą']
# prejudycjalność: ['prejudycjalne', 'prejudycjalnych']
# innej: ['jakiejkolwiek', 'samej', 'takiej', 'tej']
# skarżącej: ['pozwanej']
# innym: ['takim']
# miedzy: ['między']
# regułą: ['zasadą']
# nie: ['nigdy']
# uznając: ['uznał']
# świadczenie: ['świadczenia']
# zobowiązana: ['zobowiązany']
# umowę: ['umowy']
# brakiem: ['braku']
# kompletne: ['niekompletne']
# wówczas: ['bowiem', 'wtedy']
# takich: ['tych']
# wystawił: ['wystawiając']
# wykonał: ['wykonano']
# wynikającego: ['wynikające', 'wynikających']
# przedłożenia: ['przedłożenie']
# znaczenia: ['znaczenie']
# wynagrodzenie: ['wynagrodzenia']
# odebrania: ['odebranie']
# gdzie: ['tam']
# rozstrzygnięcia: ['rozstrzygnięcie']
# właściwy: ['odpowiedni']
# skoro: ['jeżeli']
# płaci: ['zapłacić']
# wystąpienia: ['wystąpienie']
# powyższych: ['tych']
# procesu: ['procesie']
# postępowania: ['postępowanie']
# wyniosła: ['wynosiła']
# sumę: ['kwotę']
# podstawę: ['podstawą']
# zostało: ['zostały']
# oddanie: ['oddania']
# które: ['których']
# zauważyć: ['powiedzieć']
# tym: ['samym', 'takim']
# przekazanie: ['odebranie']
# nieistotnych: ['istotnych']
# podanych: ['wskazanych']
# jednej: ['drugiej']
# nawet: ['tylko', 'wtedy']
